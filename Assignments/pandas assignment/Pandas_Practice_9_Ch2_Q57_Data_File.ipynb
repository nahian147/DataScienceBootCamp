# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("Ch2_Q57_Data_File.xlsx")

df
# Out:
#     Worker   Wage  Education  Age Unnamed: 4  \
# 0        1  17.54         12   76        NaN
# 1        2  20.93         10   61        NaN
# 2        3  12.94          8   75        NaN
# 3        4  19.34          6   38        NaN
# 4        5  24.12         12   59        NaN
# ..     ...    ...        ...  ...        ...
# 75      76  25.64         14   74        NaN
# 76      77  38.77         21   41        NaN
# 77      78  21.87         15   75        NaN
# 78      79  27.54         20   46        NaN
# 79      80  23.66         12   49        NaN
#
#                                            Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0   The manager of a human resources department of...        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                         Observation       Wage  Education
# 3                                                   1      17.54         12
# ...

# %%
df=df.iloc[:,:4]
df
# Out:
#     Worker   Wage  Education  Age
# 0        1  17.54         12   76
# 1        2  20.93         10   61
# 2        3  12.94          8   75
# 3        4  19.34          6   38
# 4        5  24.12         12   59
# ..     ...    ...        ...  ...
# 75      76  25.64         14   74
# 76      77  38.77         21   41
# 77      78  21.87         15   75
# 78      79  27.54         20   46
# 79      80  23.66         12   49
#
# [80 rows x 4 columns]

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.scatter(df['Education'], df['Wage'], marker='o', color='blue', alpha=0.5)
plt.xlabel('Years of Education')
plt.ylabel('Hourly Wage ($)')
plt.title(' Wage vs. Education')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
plt.scatter(df['Age'], df['Wage'], marker='o', color='green', alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Hourly Wage ($)')
plt.title('WAGE vs. AGE')
plt.grid(True)

# Display the scatterplot
plt.show()
