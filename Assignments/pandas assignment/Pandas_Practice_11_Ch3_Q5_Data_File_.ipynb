# %%
import pandas as pd
#import matplotlib.pyplot as plt
df=pd.read_excel("Ch3_Q5_Data_File.xlsx")

df
# Out:
#     Price                                         Unnamed: 1  \
# 0     430                                                NaN
# 1     520                                                NaN
# 2     460                                                NaN
# 3     475                                                NaN
# 4     670                                                NaN
# 5     521                                                NaN
# 6     670                                                NaN
# 7     417                                                NaN
# 8     533                                                NaN
# 9     525  Find the mean and median sale price. (Round "m...
# 10    538                                                NaN
# 11    370                                                NaN
# 12    530                                                NaN
# 13    525                                                NaN
# ...

# %%
df=df.iloc[:,:1]
df
# Out:
#     Price
# 0     430
# 1     520
# 2     460
# 3     475
# 4     670
# 5     521
# 6     670
# 7     417
# 8     533
# 9     525
# 10    538
# 11    370
# 12    530
# 13    525
# 14    430
# 15    330
# 16    575
# 17    555
# 18    521
# 19    350
# 20    399
# 21    560
# 22    440
# 23    425
# 24    669
# 25    660
# 26    702
# 27    540
# 28    460
# 29    588
# 30    445
# 31    412
# 32    735
# 33    537
# 34    630
# 35    430

# %%
#Find the mean and median sale price. (Round "mean" to 2 decimal places.)
print("Mean Sale Price:", round(df['Price'].mean(), 2))
print("Median Sale Price:", df['Price'].median())
# Out:
# Mean Sale Price: 516.03
# Median Sale Price: 523.0
