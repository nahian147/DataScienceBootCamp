# %%
import pandas as pd

# %%
df=pd.read_excel("Ch1_Q20_V12_Data_File.xlsx")

# %%
df=df.iloc[:,:4]

# %%
df
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 1             2  28.0  752.0    NaN
# 2             3  24.0  673.0  204.0
# 3             4  17.0    NaN  151.0
# 4             5  20.0   66.0  191.0
# ..          ...   ...    ...    ...
# 86           87  18.0  412.0  137.0
# 87           88  28.0  629.0  139.0
# 88           89  22.0  167.0  125.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
#
# [91 rows x 4 columns]

# %%
#a.
print("How many observations have x1 values greater than 30?")

print((df['x1'] > 30).sum())

#or
#print(len(df[df['x1']>30]))
# Out:
# How many observations have x1 values greater than 30?
# 17
# 17

# %%
#b. Sort the data by x1 in ascending order. What are the x1, x2, and x3 values of the first observation after the data are sorted?

sorted_df = df.sort_values(by='x1', ascending=True)


print("x1:", sorted_df.iloc[0]['x1'])
print("x2:", sorted_df.iloc[0]['x2'])
print("x3:", sorted_df.iloc[0]['x3'])
# Out:
# x1: 2.0
# x2: 335.0
# x3: 166.0

# %%
sorted_df = df.sort_values(by='x1', ascending=False)


print("x1:", sorted_df.iloc[0]['x1'])
print("x2:", sorted_df.iloc[0]['x2'])
print("x3:", sorted_df.iloc[0]['x3'])
# Out:
# x1: 57.0
# x2: 218.0
# x3: 154.0

# %%
sorted_df = df.sort_values(by='x1', ascending=False)
sorted_df
# Out:
#     Observation    x1     x2     x3
# 69           70  57.0  218.0  154.0
# 35           36  43.0  768.0  140.0
# 45           46  41.0   71.0   94.0
# 11           12  39.0   62.0  128.0
# 33           34  39.0  173.0  160.0
# ..          ...   ...    ...    ...
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 58           59   4.0  257.0  144.0
# 50           51   2.0  335.0  166.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]

# %%
#d. How many missing values are there in x1, x2, and x3?
print('Missing val in x1:', df['x1'].isna().sum())
print('Missing val in x2:', df['x2'].isna().sum())
print('Missing val in x3:', df['x3'].isna().sum())
# Out:
# Missing val in x1: 1
# Missing val in x2: 3
# Missing val in x3: 5
